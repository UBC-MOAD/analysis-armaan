# %% [markdown]
# Checking Solar Reconstruction: 3 hour first, then 1 hour

# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

import downscaling as ds

# %%
# Load three hour average

# %%
avg3 = xr.open_dataset('./ncfiles/vector3avg_y2007m11d05.nc')

# %%
avg3.solar[0].plot();

# %%
# and reconstruction

# %%
recon = xr.open_dataset('./ncfiles/reconCW_y2007m11d05.nc')

# %%
recon.solar[0].plot();

# %%
avg3.solar[ :,130, 150].plot();
recon.solar[ :,130, 150].plot();

# %% [markdown]
# Looks okay.  Not screaming fabulous but okay.

# %%
recon.close()

# %%
avg3.close()

# %% [markdown]
# ## Hour Reconstruction

# %%
base = xr.open_dataset('./ncfiles/Solar_v20220816__y2007m11d05.nc')
base.solar[0].plot();

# %%
reconS = xr.open_dataset('./ncfiles/reconCW1hS_y2007m11d05.nc')
reconS.solar[0].plot();

# %%
base.solar[:, 130, 150].plot();
reconS.solar[:, 130, 150].plot();

# %% [markdown]
# Not too bad.
